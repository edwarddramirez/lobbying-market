# %%
# import modules
import os, sys
import requests
import pandas as pd
from tqdm import tqdm
tqdm.pandas() # for progress_apply

import numpy as np
# Out:
# /home/edr/mambaforge/envs/cbase/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/edr/mambaforge/envs/cbase/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df = pd.read_pickle('processed_companyData.pkl') #to load 123.pkl back to the dataframe df

# %%
# find elements in df with the same "title" using group_by
# and count the number of elements in each group
df_grouped = df.groupby('title')
df_grouped_count = df_grouped.size().reset_index(name='count')
print(df_grouped_count)
# Out:
#                                      title  count
# 0                    1 800 FLOWERS COM INC      1
# 1                       10x Genomics, Inc.      1
# 2                  180 Life Sciences Corp.      2
# 3     1895 Bancorp of Wisconsin, Inc. /MD/      1
# 4                          1ST SOURCE CORP      1
# ...                                    ...    ...
# 2581                           nCino, Inc.      1
# 2582                    reAlpha Tech Corp.      1
# 2583                scPharmaceuticals Inc.      1
# 2584                       urban-gro, Inc.      1
# 2585                 vTv Therapeutics Inc.      1
#
# [2586 rows x 2 columns]

# %%
 # count the number of elements by title
df.value_counts('title')

# use value_counts to only have one element per group
df_unique = df.drop_duplicates(subset='title')

# %%
df_unique
# Out:
#      ticker                                 title  \
# 0      MSFT                        MICROSOFT CORP
# 1      AAPL                            Apple Inc.
# 2      NVDA                           NVIDIA CORP
# 3      AMZN                        AMAZON COM INC
# 4     GOOGL                         Alphabet Inc.
# ...     ...                                   ...
# 2627    DJT  Trump Media & Technology Group Corp.
# 2628   LENZ               LENZ Therapeutics, Inc.
# 2843  FRLAW         Fortune Rise Acquisition Corp
# 3042  VSACW      VISION SENSING ACQUISITION CORP.
# 3063  FHLTU               Future Health ESG Corp.
#
#                                                  assets  \
# 0     {'label': 'Assets', 'description': 'Sum of the...
# 1     {'label': 'Assets', 'description': 'Sum of the...
# 2     {'label': 'Assets', 'description': 'Sum of the...
# 3     {'label': 'Assets', 'description': 'Sum of the...
# 4     {'label': 'Assets', 'description': 'Sum of the...
# ...

# %%
df.loc[0]['assets_summary']
# Out:
#            end           val quarter  year
# 0   2009-06-30   77888000000      Q2  2009
# 1   2009-09-30   81612000000      Q3  2009
# 2   2009-12-31   82096000000      Q4  2009
# 3   2010-03-31   84910000000      Q1  2010
# 4   2010-06-30   86113000000      Q2  2010
# 5   2010-09-30   91540000000      Q3  2010
# 6   2010-12-31   92306000000      Q4  2010
# 7   2011-03-31   99727000000      Q1  2011
# 8   2011-06-30  108704000000      Q2  2011
# 9   2011-09-30  107415000000      Q3  2011
# 10  2011-12-31  112243000000      Q4  2011
# 11  2012-03-31  118010000000      Q1  2012
# 12  2012-06-30  121271000000      Q2  2012
# 13  2012-09-30  121876000000      Q3  2012
# 14  2012-12-31  128683000000      Q4  2012
# 15  2013-03-31  134105000000      Q1  2013
# 16  2013-06-30  142431000000      Q2  2013
# 17  2013-09-30  142348000000      Q3  2013
# 18  2013-12-31  153543000000      Q4  2013
# 19  2014-03-31  156119000000      Q1  2014
# 20  2014-06-30  172384000000      Q2  2014
# ...
